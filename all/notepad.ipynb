# %%
import pandas as pd
df_r = pd.read_csv("./cleaned_reviews.csv")
df_p = pd.read_csv("./cleaned_products.csv")
print(f"행 수: {len(df_r):,}, {len(df_p)}건")
print(f"컬럼: {df_r.columns.tolist()}")
df_r.to_csv("../data_ghactions/cleaned_reviews.csv.gz", index=False, compression='gzip', encoding='utf-8-sig')
df_p.to_csv("../data_ghactions/cleaned_products.csv.gz", index=False, compression='gzip', encoding='utf-8-sig')
# Out:
# C:\Users\Minsoo\AppData\Local\Temp\ipykernel_17260\2032527644.py:2: DtypeWarning: Columns (0: 구매사이즈, 1: 구매상세, 2: 퀄리티, 3: 구김, 4: 두께감, 5: 신축성, 6: 색감, 7: 보온성) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_r = pd.read_csv("./cleaned_reviews.csv")
# 행 수: 688,713, 2986건
# 컬럼: ['리뷰번호', 'goodsNo', '리뷰타입', '작성자', '리뷰내용', '평점', '체험단', '구매옵션', '키', '몸무게', '성별', '작성일', '만족도', '사진유무', '도움돼요', '구매사이즈', '구매상세', '연도', '월', '일', '요일', '평점_raw', '만족도_응답여부', '사이즈', '화면대비색감', '퀄리티', '구김', '두께감', '신축성', '색감', '보온성', '퀄리티_점수', '보온성_점수', '신축성_점수', '두께감_점수', '구김_점수', '사이즈_편차', '사이즈_편차절대', '화면대비색감_편차', '화면대비색감_편차절대', '색감_편차', '색감_편차절대']

# %%
import pandas as pd
df = pd.read_parquet("../data_ghactions/embedding_input.parquet")
print(f"행 수: {len(df):,}")
print(f"컬럼: {df.columns.tolist()}")
print(df.head())
print(df.dtypes)
# Out:
# 행 수: 758
# 컬럼: ['리뷰번호', '리뷰내용_clean', 'goodsNo', '리뷰타입', '평점', '작성일', '사이즈', '화면대비색감', '퀄리티', '구김', '두께감', '신축성', '퀄리티_점수', '신축성_점수', '두께감_점수', '구김_점수', '사이즈_편차절대', '화면대비색감_편차절대', '만족도_응답여부', 'laugh_count', 'cry_count', 'exclamation_count', 'question_count', 'emoji_count', 'has_repetition', 'text_length_orig', '성별', '구매사이즈', '구매상세', '사진유무', '체험단', '브랜드', '카테고리']
#        리뷰번호                                         리뷰내용_clean   goodsNo  \
# 0  59506115  체형마다 다르겠지만 제 기준 목 부분이 굉장히 볼품없어 보이는 느낌 이너라면 모를까...   4022786
# 1  60685890                   무신사에서 드디어 저의 남편에게 잘맞는 옷을 찾았습시다^^  ﻿4022786
# 2  74956362                       여름엔 셋업이 최고에요 재질도 좋고 시원해서 좋아요   5060359
# 3  75140957                    꽤 얇고 반팔이라서 편하게 입기좋고 바지도 얇아서 좋아요   5060359
# 4  75971570  저렴하고 바지랑 셔츠가 얇아서 한여름에도 입을수있을거같아요 디자인도 이쁨니다 브라운...   5060359
#
#       리뷰타입   평점                  작성일  사이즈 화면대비색감  퀄리티   구김  ... emoji_count  \
# 0    goods  2.0  2024-05-17 14:53:26  NaN    NaN  NaN  NaN  ...           0
# ...

# %%
df['브랜드']
df['카테고리'].value_counts()
# Out:
# 카테고리
# 상의     461
# 아우터    152
# 하의     145
# Name: count, dtype: int64
